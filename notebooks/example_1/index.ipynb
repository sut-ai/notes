# %% [markdown]
# # DFS ALGORITHM

# %% [markdown]
# #QUESTION
# We call a number flowing, if differences of two adjacent digits is 1.( e.g., 454, 321). Give an O(n)-time algorithm using DFS to find every flowing number that is less than n.

# %% [markdown]
# #SOLUTION:

# %% [markdown]
# #Step1:
# for number [1-9] ---> we call DFS

# %%
int n=8 , m=13
for i in range(8)
   dfs(n,m,i)

# %% [markdown]
# #Step2:
# now we see that the number we have given whether it's in  [m-n] or not ?
# if it wasn't in that span ---> it is not our  desired

# %%
#stepNum --> the number we have given from 
if stepNum <= m && stepNum >=n
    print(stepNum)
elif stepNum == 0 || stepNum >m
   return

# %% [markdown]
# #Step3 :
# now we create 3 number from that number we have given.
# "lastDigit" --> show the single digit
# "A,B" --> flowing number has got two state ,it can be smaller than previous number or bigger than it

# %%
int lastDigit = stepNum % 10
int A =stepNUm * 10 + (lastDigit -1)
int B =stepNum *10 +(lastDigit +1)

# %% [markdown]
# #Step4 :
# now we find out the single digit that we have calculated ,if it wasn't 0 or 9 ,we run DFS method for A and B in same time

# %%
if lastDigit == 0
    dfs(n,m,B)
elif lastDigit == 9
    dfs(n,m,A)
else 
    dfs(n,m,A)
    dfs(n,m,B)

# %% [markdown]
# ![WhatsApp%20Image%202021-03-15%20at%201.20.35%20AM.jpeg](attachment:WhatsApp%20Image%202021-03-15%20at%201.20.35%20AM.jpeg)

# %% [markdown]
# # BFS ALGORITHM

# %% [markdown]
# #QUESTION
# Suppose that G = ( V , E ) be connected graph with n vertices. We have a tree by running BFS on G that starts from r، distinguished point. Give an O(n)-time algorithm that gets two different vertices Vi and Vj at G and return their lowest common ancestors at BFS.

# %% [markdown]
# #SOLUTION:

# %% [markdown]
# #Step 1:
# we create a "node" class, it has got one node,father,index of that node and ArrayList of children nodes

# %%
class Node:
    Node father
    children = array(Node)
    int index
    nodes = array(Node)

# %% [markdown]
# #Step 2:
# now we must find Vi and Vj

# %%
for i in range(n)
     if node.get(i).index ==j
            V_j=node.get(i)
    else node.get(i).index == i
            V_i=node.get(i)

# %% [markdown]
# #Step 3:
# now we put any index of node in array then we find the father of that node and put it in array (we continue to see the root)

# %%
j_indexs=array(node)
Node current =V_j
j_index.insert(current)

while current != none
    j_index.insert(current)
    current=current.father

# %% [markdown]
# now we define two pointer ---> P_i and P_j
# then we forward pointer P_j size of j-i if the both index of P_j and P_i are equally --> we find the answer
# if it wasn't we forward the pointer step by step until end

# %% [markdown]
# ![WhatsApp%20Image%202021-03-15%20at%201.26.03%20AM.jpeg](attachment:WhatsApp%20Image%202021-03-15%20at%201.26.03%20AM.jpeg)

# %% [markdown]
# ![WhatsApp%20Image%202021-03-15%20at%201.40.30%20AM.jpeg](attachment:WhatsApp%20Image%202021-03-15%20at%201.40.30%20AM.jpeg)
